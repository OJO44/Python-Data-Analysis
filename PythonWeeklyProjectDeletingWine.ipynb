# %% [markdown]
# <a href="https://colab.research.google.com/github/OJO44/Python-Data-Analysis/blob/main/PythonWeeklyProjectDeletingWine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Wine**

# %%
#Step 1. Import the necessary libraries
import pandas as pd

import numpy as np

# %%
#Step 2. Import the dataset from this address.
#Step 3. Assign it to a variable called wine
data = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data"
wine = pd.read_csv(data)
wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
#Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns
wine.columns
wine= wine.drop(["1", "2.43","2.8",".28","5.64", "3.92","1065"], axis=1)
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %%
#tep 5. Assign the columns as below:
#The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
#alcohol
#malic_acid
#alcalinity_of_ash
#magnesium
#flavanoids
#proanthocyanins
#hue

wine.columns = ['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue']
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %%
#Step 6. Set the values of the first 3 rows from alcohol as NaN
wine.loc[:2, 'alcohol'] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %%
#Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN
wine.loc[2:3, 'magnesium'] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8        NaN        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %%
#Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium
wine['alcohol'].fillna(10, inplace=True)
wine['magnesium'].fillna(100, inplace=True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %%
#Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium
wine['alcohol'].fillna(10, inplace=True)
wine['magnesium'].fillna(100, inplace=True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %%
#Step 9. Count the number of missing values
missing_values_count = wine.isnull().sum()
print(missing_values_count)
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %%
#Step 10. Create an array of 10 random numbers up until 10
random_array = np.random.randint(1, 11, size=10)
print(random_array)
# Out:
# [6 5 1 5 1 4 3 9 6 4]

# %%
#Step 11. Use random numbers you generated as an index and assign NaN value to each of cell.
wine = wine.reindex(random_array)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 6    14.06        2.15               17.6      121.0        2.51
# 5    14.39        1.87               14.6       96.0        2.52
# 1    10.00        2.36               18.6      101.0        3.24
# 5    14.39        1.87               14.6       96.0        2.52
# 1    10.00        2.36               18.6      101.0        3.24
#
#    proanthocyanins   hue
# 6             1.25  1.06
# 5             1.98  1.02
# 1             2.81  1.03
# 5             1.98  1.02
# 1             2.81  1.03

# %%
#Step 12. How many missing values do we have?
missing_value_count = wine.isnull().sum().sum()
print(missing_values_count)
# Out:
# 0

# %%
#Step 13. Delete the rows that contain missing values
wine = wine.dropna()
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 6    14.06        2.15               17.6      121.0        2.51
# 5    14.39        1.87               14.6       96.0        2.52
# 1    10.00        2.36               18.6      101.0        3.24
# 5    14.39        1.87               14.6       96.0        2.52
# 1    10.00        2.36               18.6      101.0        3.24
#
#    proanthocyanins   hue
# 6             1.25  1.06
# 5             1.98  1.02
# 1             2.81  1.03
# 5             1.98  1.02
# 1             2.81  1.03

# %%
#Step 14. Print only the non-null values in alcohol
print(wine['alcohol'].dropna())
# Out:
# 6    14.06
# 5    14.39
# 1    10.00
# 5    14.39
# 1    10.00
# 4    14.20
# 3    13.24
# 9    14.10
# 6    14.06
# 4    14.20
# Name: alcohol, dtype: float64

# %%
#Step 15. Reset the index, so it starts with 0 again
wine = wine.reset_index(drop=True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    14.06        2.15               17.6      121.0        2.51
# 1    14.39        1.87               14.6       96.0        2.52
# 2    10.00        2.36               18.6      101.0        3.24
# 3    14.39        1.87               14.6       96.0        2.52
# 4    10.00        2.36               18.6      101.0        3.24
#
#    proanthocyanins   hue
# 0             1.25  1.06
# 1             1.98  1.02
# 2             2.81  1.03
# 3             1.98  1.02
# 4             2.81  1.03

# %%
#forage
#our wrld in data
